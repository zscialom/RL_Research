# %% [markdown]
# <a href="https://colab.research.google.com/github/zscialom/RL_Research/blob/test/Optimal_Policy_Analysis_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt  # for plotting
import numpy as np

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ticker='GOOG'
lmbdas= [0.001,0.01,0.1,0.5] # 0.01

# %%
figure_folder_matrix = "/content/drive/Shared drives/ProjectML/Project/Q-matrices/" + ticker  

pis=[]
Qs=[]
for i, lmbda in enumerate(lmbdas):
  q_file_name = 'qmatrix_lmbda_' + str(lmbda) + '.npy'
  path = "%s/%s" % (figure_folder_matrix, q_file_name)
  Q = np.load(path)
  num_blocks, num_prices= np.shape(Q)[0:2]
  pi=np.zeros([num_blocks, num_prices])
  for X in range(num_blocks):
   for M in range(num_prices):
     pi[X,M] = Q[X,M,:].argmax() 
  Qs.append(Q)
  pis.append(pi)

# %%
fig = plt.figure(figsize=(35,5))

for i in range(len(lmbdas)):
  
  ax = fig.add_subplot(1,5,i+1)
  #plt.subplot(4,2,i+1)
 
  #heatmap = ax.pcolor(pis[i], cmap=plt.cm.Blues)

# put the major ticks at the middle of each cell
#ax.set_xticks(np.arange(pi.shape[0])+0.5, minor=False)
#ax.set_yticks(np.arange(pi.shape[1])+0.5, minor=False)
 
  ax.xaxis.tick_top()
  pos = ax.imshow(pis[i], cmap='Blues', interpolation='bicubic')
  ax.invert_yaxis()
  ax.set_xlabel('Price index')
  ax.set_xlim([25,500])
  ax.set_ylabel('Inventory')
  ax.set_title('$\lambda=%2.2f$'%lmbdas[i])

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
  
  # want a more natural, table-like display
  #plt.grid(color="k", linestyle='-', linewidth=1)
  ax.set_xlabel('Price index')
  ax.set_ylabel('Inventory')
  #ax.set_xticklabels(row_labels, minor=False)
  #ax.set_yticklabels(column_labels, minor=False)
fig.colorbar(pos, ax=ax)  
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
for i,ax in enumerate(axes.flat):
    im = ax.imshow(pis[i], vmin=0, vmax=4)
    ax.invert_yaxis()
    #ax.set_xlim([25,130])
   
    ax.set_title('$\lambda=%2.2f$'%lmbdas[i])
    ax.set_xlabel('Price index')
    ax.set_ylabel('Inventory')
    ax.grid(color='w')


fig.subplots_adjust(right=0.8)
fig.subplots_adjust(hspace=0.7)
cbar_ax = fig.add_axes([0.95, 0.15, 0.05, 0.7])
fig.tight_layout()
fig.colorbar(im, cax=cbar_ax)

plt.show()
# Out:
# <ipython-input-9-160b50fa0c7d>:16: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
plt.imshow(pi)
plt.grid(color="w", linestyle='--', linewidth=0.3)

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.invert_yaxis()
ax.xaxis.tick_top()
pos = ax.imshow(pi, cmap='Blues', interpolation='bicubic')
ax.invert_yaxis()
ax.set_xlabel('Price index')
ax.set_xlim([25,500])
ax.set_ylabel('Inventory')
ax.set_title('$\lambda=%2.2f$'%lmbda)
# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
